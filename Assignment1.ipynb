# %% [markdown]
# <a href="https://colab.research.google.com/github/20023158uhi/20023158_DataAnalytics/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Main Findings
#
# -
# -
# -

# %% [markdown]
# # Introduction
#
# In this report, the aim was to investigate the relationship between weather and traffic collisions on a given day. The goal was to perform set of analyses on collison data so that regression models could be built and used the the  to predict the number of collisions on the particular day so that the New York City
# emergency services could optimise their response staff.

# %% [markdown]
# # Methodology

# %%
collated_collisions <- read_csv("https://raw.githubusercontent.com/20023158uhi/20023158_DataAnalytics/main/results-20210103-195108.csv")

head(collated_collisions)
# Out:
# ── Column specification ────────────────────────────────────────────────────────
# cols(
#   day = col_double(),
#   year = col_double(),
#   mo = col_character(),
#   da = col_character(),
#   collision_date = col_date(format = ""),
#   temp = col_double(),
#   dewp = col_double(),
#   slp = col_double(),
#   visib = col_double(),
#   wdsp = col_double(),
#   mxpsd = col_double(),
#   gust = col_double(),
#   max = col_double(),
#   min = col_double(),
#   prcp = col_double(),
#   sndp = col_double(),
#   fog = col_double(),
#   NUM_COLLISIONS = col_double()
# )
#   day year mo da collision_date temp dewp slp    visib wdsp mxpsd gust  max
# 1 5   2020 01 24 2020-01-24     37.3 33.7 1028.5  6.5   3.3  8    999.9 46.0
# 2 2   2020 01 07 2020-01-07     39.0 26.6 1016.6 10.0   8.0 13    999.9 43.0
# 3 1   2020 01 13 2020-01-13     42.5 37.0 1029.6  9.5   9.2 13    999.9 57.0
# 4 3   2020 01 15 2020-01-15     43.9 38.3 1019.4  8.2   5.4 14     15.0 51.1
# ...

# %% [markdown]
# # Results

# %%
library(tidyverse)

# %% [markdown]
# The collated collisions dated was used to plot the number of collision on each day of the year across all the years being investigated

# %%
plot(collated_collisions$collision_date, collated_collisions$NUM_COLLISIONS, main = "Number of Collisions on Each day of the Year")
# Out:
# Plot with title “Number of Collisions on Each day of the Year”

# %% [markdown]
# # Conclusions

# %% [markdown]
# # References
